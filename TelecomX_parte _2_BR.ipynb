# %% [markdown]
# #📌 Extracão

# %%
import json


#Load the JSON data

with open('TelecomX_Data.json','r') as f:
    data = json.load(f)

print(data)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #🔧 Transformação

# %%
import pandas as pd

df = pd.DataFrame(data)

print(df)
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
# Separa apenas as colunas Customer ID, Churn e Account

df_churn= df[['customerID', 'Churn', 'account']]

print(df_churn)
# Out:
#       customerID Churn                                            account
# 0     0002-ORFBO    No  {'Contract': 'One year', 'PaperlessBilling': '...
# 1     0003-MKNFE    No  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     0004-TLHLJ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     0011-IGKFF   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     0013-EXCHZ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  9992-RRAMN   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  9992-UJOEL    No  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  9993-LHIEB    No  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  9995-HOTOH    No  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 3 columns]

# %%
# Considerando apenas as linhas de Churn que contém Yes

df_churnY = df_churn[df_churn['Churn'] == 'Yes']

print(df_churnY)
# Out:
#       customerID Churn                                            account
# 2     0004-TLHLJ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     0011-IGKFF   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     0013-EXCHZ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 18    0022-TCJCI   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# 19    0023-HGHWL   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...          ...   ...                                                ...
# 7243  9961-JBNMK   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7246  9965-YOKZB   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7260  9985-MWVIX   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7261  9986-BONCE   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7263  9992-RRAMN   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
#
# [1869 rows x 3 columns]

# %% [markdown]
# #📊 Carga e análise

# %%
# Analisando o tipo de contrato - month-to-month

df_churnMM = df_churnY[df_churnY['account'].apply(lambda x: x['Contract'] == 'Month-to-month')]

print(df_churnMM)
# Out:
#       customerID Churn                                            account
# 2     0004-TLHLJ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     0011-IGKFF   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     0013-EXCHZ   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 19    0023-HGHWL   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 21    0023-XUOPT   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...          ...   ...                                                ...
# 7243  9961-JBNMK   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7246  9965-YOKZB   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7260  9985-MWVIX   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7261  9986-BONCE   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7263  9992-RRAMN   Yes  {'Contract': 'Month-to-month', 'PaperlessBilli...
#
# [1655 rows x 3 columns]

# %%
# Analisando o tipo de contrato - one year

df_churnOY = df_churnY[df_churnY['account'].apply(lambda x: x['Contract'] == 'One year')]

print(df_churnOY)
# Out:
#       customerID Churn                                            account
# 18    0022-TCJCI   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# 68    0112-QWPNC   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# 113   0193-ESZXP   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# 119   0201-OAMXR   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# 120   0203-HHYIJ   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# ...          ...   ...                                                ...
# 6908  9518-RWHZL   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# 6945  9565-JSNFM   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# 7013  9651-GTSAQ   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# 7148  9831-BPFRI   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
# 7150  9835-ZIITK   Yes  {'Contract': 'One year', 'PaperlessBilling': '...
#
# [166 rows x 3 columns]

# %%
# Analisando o tipo de contrato - two year

df_churnTY = df_churnY[df_churnY['account'].apply(lambda x: x['Contract'] == 'Two year')]

print(df_churnTY)
# Out:
#       customerID Churn                                            account
# 421   0607-DAAHE   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 428   0617-AQNWT   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 644   0917-EZOLA   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 729   1043-YCUTE   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 812   1150-WFARN   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 1029  1447-PJGGA   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 1080  1527-SXDPN   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 1099  1555-DJEQW   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 1206  1725-IQNIY   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 1555  2225-ZRGSG   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 1782  2530-ENDWQ   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# 1784  2533-QVMSK   Yes  {'Contract': 'Two year', 'PaperlessBilling': '...
# ...

# %%
# Contando a quantidade de pessoas com contrato - Two year

count_churnTY = len(df_churnTY)

print(count_churnTY)
# Out:
# 48

# %%
# Contando a quantidade de pessoas evasivas

count_churnY = len(df_churnY)

print(count_churnY)
# Out:
# 1869

# %%
# Analisando a porcentagem dos 3 tipos de contrato

percentage_churnMM = (len(df_churnMM) / count_churnY) * 100
percentage_churnOY = (len(df_churnOY) / count_churnY) * 100
percentage_churnTY = (len(df_churnTY) / count_churnY) * 100

print(percentage_churnMM)
print(percentage_churnOY)
print(percentage_churnTY)
# Out:
# 88.55002675227395
# 8.881754949170679
# 2.568218298555377

# %%
# Arredondando as médias adquiridas

percentage_churnMM = round(percentage_churnMM, 2)
percentage_churnOY = round(percentage_churnOY, 2)
percentage_churnTY = round(percentage_churnTY, 2)

print(f'A porcentagem do plano mensal é: {percentage_churnMM} %')
print(f'A porcentagem do plano anual é: {percentage_churnOY} %')
print(f'A porcentagem do plano biênio é: {percentage_churnTY} %')
# Out:
# A porcentagem do plano mensal é: 88.55 %
# A porcentagem do plano anual é: 8.88 %
# A porcentagem do plano biênio é: 2.57 %

# %%
import matplotlib.pyplot as plt

# Plotting the percentage pie chart

labels = ['Month-to-month', 'One year', 'Two year']
sizes = [percentage_churnMM, percentage_churnOY, percentage_churnTY]
colors = ['#ff9999','#66b3ff','#99ff99']
explode = (0.1, 0, 0)  # explode 1st slice

plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Percentage of Churned Customers by Contract Type')
plt.show()

# %% [markdown]
# #📄Relatorio Final

# %% [markdown]
# Relatório
#
# Objetivo:
# Realizar um estudo analítico sobre a possível prevensão de evasão de clientes por meio de dados didponibilizados pela TelecomX.
#
# Desenvolvimento:
#
# O presente estudo foi realizado dividido em 3 fases: extração, tratamento dos dados e a análise, adiante faremos uma breve narrativa sobre os mesmos.
# Na fase Extração foi trabalho a conversão dos dados incialmente contidos no tipo .JSON para a realização de sua leitura no Pyton por meio da utilização do Panda e seu dicionários já realizados no projeto anterior.
# O tratamento de dados foi realizado de modo a separar dados específicos em busca de variáveis - Customer ID, Churn e Account - que fizessem sentido para a situação proposta.
# Por fim, a análise nos mostra partes relevante do sistema vivenciado pela empresa neste momento em relação aos 3 planos oferecidos pela empresa.
#
# Conclusão:
#
# - A empresa possui 1869 casos de evasão no momento;
# - A análise realiza foi mediante a apenas ao estudos das opções de planos oferecidos pela TelecomX;
# - Os planos dividos em mensal, anual e biênio apresentam as seguintes porcentagens: 88,6%, 8,9% e 2,6% respectvamente.
# - O plano mensal é o que tem apresentado a maior quantidade de evasão;
# - Quanto mais tempo o cliente fica na empresa, menos ele pensa na evasão.
